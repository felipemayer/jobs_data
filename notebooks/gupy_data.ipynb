# %% [markdown]
# # Job crawler - Gupy

# %% [markdown]
# #### Load Libs

# %%
import requests
import pandas as pd
from datetime import date
import time
import random
from google.cloud import bigquery
import pandas_gbq
import warnings
warnings. filterwarnings("ignore")

# %% [markdown]
# #### Load raw data

# %%
def normalize_columns(df):
    # Renomeando colunas
    df_new = df[['portal', 'term','date_extraction', 'name', 'description', \
            'careerPageName', 'type', 'publishedDate', \
            'applicationDeadline', 'isRemoteWork', 'city', \
                'state', 'country', 'jobUrl', 'careerPageUrl']]
    
    df_new.rename(columns={'careerPageName': 'company_name', 
                            'publishedDate': 'published_date', 
                            'applicationDeadline': 'application_deadline', 
                            'isRemoteWork': 'is_remote_work', 
                            'jobUrl': 'job_url', 
                            'careerPageUrl': 'company_url'}, inplace=True)
    return df_new

# %%
# defining the url to get the data
url = "https://portal.api.gupy.io/api/job"

# defining the job title to search for
search_terms = ['Data', 'dados']

# defining the dataframe to store the data
df_jobs_raw = pd.DataFrame()

# defining today to use in some cases
today = date.today()

for term in search_terms:
    querystring = {"name":term,"offset":"1","limit":"5000"}

    time.sleep(random.randint(3, 6))
    r = requests.request("GET", url, params=querystring)

    data = r.json()

    df_term = pd.json_normalize(data, record_path =['data'])
    df_term['portal'] = "Gupy"
    df_term['term'] = term
    df_term['date_extraction'] = today

    df_jobs_raw = pd.concat([df_jobs_raw, df_term], ignore_index=True)
    df_jobs_normalized = normalize_columns(df_jobs_raw)

df_jobs = df_jobs_normalized.copy()

display(df_jobs.head())
# Out:
#   portal  term date_extraction  \
# 0   Gupy  Data      2023-04-19
# 1   Gupy  Data      2023-04-19
# 2   Gupy  Data      2023-04-19
# 3   Gupy  Data      2023-04-19
# 4   Gupy  Data      2023-04-19
#
#                                                 name  \
# 0   Analista Data Center JR - Virtualização (VMWare)
# 1  ANALISTA II BIG DATA - GOIÂNIA/GO II || POI - ...
# 2                           Estágio em Data Quality
# 3                  Assistente de Data Quality [LETT]
# 4            Assistente de Data Quality (Manutenção)
#
#                                          description  \
# 0  SOBRE A EMPRESA:A Unidade de Negócio de Cloud ...
# 1  Para compor ainda mais esse time de sucesso, b...
# 2  Quer fazer parte de um time alta performance?&...
# 3  Quer fazer parte de um time alta performance?&...
# 4  Quer fazer parte de um time alta performance?&...
#
#                                 company_name                     type  \
# 0                            Telefónica Tech   vacancy_type_effective
# 1  Evolução profissional a gente faz em casa   vacancy_type_effective
# 2                          Neogrid Carreiras  vacancy_type_internship
# 3                          Neogrid Carreiras   vacancy_type_effective
# 4                          Neogrid Carreiras   vacancy_type_effective
#
#              published_date application_deadline  is_remote_work  \
# 0  2023-04-19T12:05:04.822Z                 None           False
# 1  2023-04-18T19:14:00.918Z                 None           False
# 2  2023-04-18T17:48:42.627Z                 None            True
# 3  2023-04-18T17:27:18.497Z                 None            True
# 4  2023-04-18T17:25:43.453Z                 None           False
#
#                   city              state country  \
# 0  Santana de Parnaíba          São Paulo  Brasil
# 1              Goiânia              Goiás  Brasil
# 2         Porto Alegre  Rio Grande do Sul  Brasil
# 3            São Paulo          São Paulo  Brasil
# 4            São Paulo          São Paulo  Brasil
#
#                                              job_url  \
# 0  https://ttech.gupy.io/job/eyJqb2JJZCI6NDcwMzc0...
# 1  https://poi.gupy.io/job/eyJqb2JJZCI6NDY5ODUyNy...
# 2  https://neogridcarreiras.gupy.io/job/eyJqb2JJZ...
# 3  https://neogridcarreiras.gupy.io/job/eyJqb2JJZ...
# 4  https://neogridcarreiras.gupy.io/job/eyJqb2JJZ...
#
#                                          company_url
# 0  https://ttech.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bv...
# 1  https://poi.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bvcn...
# 2  https://neogridcarreiras.gupy.io/eyJzb3VyY2UiO...
# 3  https://neogridcarreiras.gupy.io/eyJzb3VyY2UiO...
# 4  https://neogridcarreiras.gupy.io/eyJzb3VyY2UiO...

# %% [markdown]
# #### Understanding and cleaning data

# %%
df_jobs.describe()
# Out:
#        portal   term date_extraction               name  \
# count     692    692             692                692
# unique      1      2               1                599
# top      Gupy  dados      2023-04-19  Analista de Dados
# freq      692    547             692                 17
#
#                                               description     company_name  \
# count                                                 692              692
# unique                                                666              360
# top     Destinado a formados dos cursos de Sistemas de...  Stefanini Group
# freq                                                    4               19
#
#                           type            published_date  \
# count                      692                       692
# unique                       8                       685
# top     vacancy_type_effective  2023-02-28T01:13:17.152Z
# freq                       518                         2
#
#             application_deadline is_remote_work       city      state country  \
# count                         33            692        692        692     692
# unique                        16              2         98         17       8
# top     2023-04-24T00:00:00.000Z          False  São Paulo  São Paulo  Brasil
# freq                           5            436        240        344     605
#
#                                                   job_url  \
# count                                                 692
# unique                                                685
# top     https://peers.gupy.io/job/eyJqb2JJZCI6NDI4MTc4...
# freq                                                    2
#
#                                               company_url
# count                                                 692
# unique                                                364
# top     https://stefanini.gupy.io/eyJzb3VyY2UiOiJndXB5...
# freq                                                   19

# %% [markdown]
# ##### Change datatypes

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   portal                692 non-null    object
#  1   term                  692 non-null    object
#  2   date_extraction       692 non-null    object
#  3   name                  692 non-null    object
#  4   description           692 non-null    object
#  5   company_name          692 non-null    object
#  6   type                  692 non-null    object
#  7   published_date        692 non-null    object
#  8   application_deadline  33 non-null     object
#  9   is_remote_work        692 non-null    bool
#  10  city                  692 non-null    object
#  11  state                 692 non-null    object
#  12  country               692 non-null    object
#  13  job_url               692 non-null    object
#  14  company_url           692 non-null    object
# dtypes: bool(1), object(14)
# memory usage: 76.5+ KB

# %%
# change columns to datetime
cols = ['date_extraction', 'application_deadline', 'published_date']

for col in cols:
    df_jobs[col] = pd.to_datetime(df_jobs[col], format="%Y-%m-%d")

# %%
# change columns to category
cols = ['term', 'type', 'city', 'state', 'country']

for col in cols:
    df_jobs[col] = df_jobs[col].astype('category')

# %%
df_jobs['published_date']
# Out:
# 0     2023-04-19 12:05:04.822000+00:00
# 1     2023-04-18 19:14:00.918000+00:00
# 2     2023-04-18 17:48:42.627000+00:00
# 3     2023-04-18 17:27:18.497000+00:00
# 4     2023-04-18 17:25:43.453000+00:00
#                     ...
# 687          2021-03-01 22:36:58+00:00
# 688          2021-01-08 21:01:27+00:00
# 689          2020-12-05 21:45:14+00:00
# 690          2020-05-29 19:52:41+00:00
# 691          2020-03-31 19:21:48+00:00
# Name: published_date, Length: 685, dtype: datetime64[ns, UTC]

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 685 entries, 0 to 691
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   portal                685 non-null    object
#  1   term                  685 non-null    category
#  2   date_extraction       685 non-null    datetime64[ns]
#  3   name                  685 non-null    object
#  4   description           685 non-null    object
#  5   company_name          685 non-null    object
#  6   type                  685 non-null    category
#  7   published_date        685 non-null    datetime64[ns, UTC]
#  8   application_deadline  33 non-null     datetime64[ns, UTC]
#  9   is_remote_work        685 non-null    bool
#  10  city                  685 non-null    category
#  11  state                 685 non-null    category
#  12  country               685 non-null    category
#  13  job_url               685 non-null    object
#  14  company_url           685 non-null    object
# dtypes: bool(1), category(5), datetime64[ns, UTC](2), datetime64[ns](1), object(6)
# memory usage: 61.9+ KB

# %% [markdown]
# ##### Check missing values

# %%
df_jobs.isna().sum()
# Out:
# portal                    0
# term                      0
# date_extraction           0
# name                      0
# description               0
# company_name              0
# type                      0
# published_date            0
# application_deadline    659
# is_remote_work            0
# city                      0
# state                     0
# country                   0
# job_url                   0
# company_url               0
# dtype: int64

# %% [markdown]
# ##### Fixing duplicated values

# %%
# check for duplicated rows
df_jobs.duplicated().sum()
# Out:
# 0

# %%
# see if any data is duplicated for job_url column and drop it
print(f"Duplicated before: {df_jobs.duplicated(subset='job_url').sum()}" )
df_jobs.drop_duplicates(subset='job_url', inplace=True)

print(f"Duplicated after: {df_jobs.duplicated(subset='job_url').sum()}")
# Out:
# Duplicated before: 7
# Duplicated after: 0

# %%
df_jobs.sample(20)
# Out:
#     portal   term date_extraction  \
# 215   Gupy  dados      2023-04-19
# 198   Gupy  dados      2023-04-19
# 270   Gupy  dados      2023-04-19
# 445   Gupy  dados      2023-04-19
# 196   Gupy  dados      2023-04-19
# 396   Gupy  dados      2023-04-19
# 570   Gupy  dados      2023-04-19
# 522   Gupy  dados      2023-04-19
# 582   Gupy  dados      2023-04-19
# 321   Gupy  dados      2023-04-19
# 337   Gupy  dados      2023-04-19
# 306   Gupy  dados      2023-04-19
# 331   Gupy  dados      2023-04-19
# 183   Gupy  dados      2023-04-19
# 12    Gupy   Data      2023-04-19
# 324   Gupy  dados      2023-04-19
# 305   Gupy  dados      2023-04-19
# 552   Gupy  dados      2023-04-19
# 412   Gupy  dados      2023-04-19
# 381   Gupy  dados      2023-04-19
#
#                                                   name  \
# 215                         Engenheiro de Dados Sênior
# 198  Cientista de Dados Especialista I (Lojas e Fra...
# 270             Engenheiro de Dados Sênior (Tech Lead)
# 445  Analista de Dados JR (Vaga afirmativa para pes...
# 196                      ANALISTA DE DADOS SR - MOVIDA
# 396                             ENGENHEIRO DE DADOS PL
# 570                      Especialista Ciência de Dados
# 522                      Analista de Migração de Dados
# 582  Advogado(a) Pleno - Proteção de Dados e Privac...
# 321                 Vaga Analista de Automação e Dados
# 337                            Analista de Dados (ETL)
# 306                               Analista de Dados PL
# 331  [Estágio] Speed Lebre | Automação e Modelagem ...
# 183                      Estagiário(a) - Dados Mestres
# 12                         Operador Data Center Cloud*
# 324       Estágio - Análise e desenvolvimento de dados
# 305                              Itaú Paraguai | Dados
# 552                      Analista de Migração de Dados
# 412  Coordenador(a) Inteligência de Dados - Custome...
# 381                   Administrador de Banco de Dados
#
#                                            description  \
# 215  # Quem somos?&nbsp;📲A&nbsp;3CON&nbsp;é enabler...
# 198  O que é o&nbsp;gb.tech?&nbsp;&nbsp;Somos o tim...
# 270  O QUE É SER UM MUTANT?Quando você decide ser M...
# 445  Nós estamos procurando um talento para se torn...
# 196  OLÁ, SEJA BEM VINDO AO MOVE CARREIRAS, RECRUTA...
# 396  Fazer parte da Afinz é integrar uma empresa qu...
# 570  Integrar o time de dados de Cognição significa...
# 522  Estamos selecionando Analista de TI com o obje...
# 582  Se você é apaixonado(a) por Direito, Tecnologi...
# 321  Estamos procurando um analista para se juntar ...
# 337  Olá!Somos o Polo Sumicity! Provedor de interne...
# 306  +30.000 pessoas, 41 países, 44 línguas.Na Cons...
# 331  Somos a empresa que conecta toda a cadeia prod...
# 183  O Estagiário na área de Dados Mestres será res...
# 12   A Unidade de Negócio de Cloud da Telefónica Te...
# 324  25 anos de história e mais de 300 clientes em ...
# 305  Evolucionar y acompañar al equipo de RRHH de B...
# 552  O EVO: Somos a melhor e mais completa platafor...
# 412  A equipe de Customer Performance LATAM da Nutr...
# 381  A Minsait é uma companhia global de tecnologia...
#
#                     company_name                     type  \
# 215          3CON | IT & Digital   vacancy_type_effective
# 198              Grupo Boticário   vacancy_type_effective
# 270                       Mutant   vacancy_type_effective
# 445                      Embraer   vacancy_type_effective
# 196  Recrutamento Interno SIMPAR   vacancy_type_effective
# 396                        Afinz   vacancy_type_effective
# 570                      Sicredi   vacancy_type_effective
# 522               Larco Petroleo   vacancy_type_effective
# 582               Peck Advogados   vacancy_type_associate
# 321                     evermart     vacancy_legal_entity
# 337                     Sumicity   vacancy_type_effective
# 306              Stefanini Group   vacancy_type_effective
# 331                        Liber  vacancy_type_internship
# 183                     Servimed  vacancy_type_internship
# 12               Telefónica Tech   vacancy_type_effective
# 324          Oliveira & Antunes   vacancy_type_internship
# 305  International Experience ✈    vacancy_type_effective
# 552                      EVO W12   vacancy_type_effective
# 412   Nutrien Soluções Agrícolas   vacancy_type_effective
# 381     Minsait an Indra Company   vacancy_type_effective
#
#                       published_date      application_deadline  \
# 215 2023-04-14 14:08:44.801000+00:00                       NaT
# 198 2023-04-14 20:49:51.321000+00:00 2023-04-28 00:00:00+00:00
# 270 2023-04-10 13:48:16.934000+00:00                       NaT
# 445 2023-03-13 18:57:28.031000+00:00                       NaT
# 196 2023-04-14 21:00:48.496000+00:00 2023-04-21 00:00:00+00:00
# 396 2023-03-22 14:04:17.547000+00:00                       NaT
# 570 2023-01-16 12:16:22.586000+00:00                       NaT
# 522 2023-02-10 19:22:29.017000+00:00                       NaT
# 582 2023-01-06 15:31:30.424000+00:00                       NaT
# 321 2023-03-31 22:11:55.983000+00:00                       NaT
# 337 2023-03-30 23:21:54.880000+00:00                       NaT
# 306 2023-04-04 13:01:08.008000+00:00                       NaT
# 331 2023-03-31 15:07:47.524000+00:00                       NaT
# 183 2023-04-17 19:53:33.974000+00:00                       NaT
# 12  2023-04-14 12:21:19.986000+00:00                       NaT
# 324 2023-03-31 20:28:39.447000+00:00                       NaT
# 305 2023-04-04 14:21:14.478000+00:00                       NaT
# 552 2023-01-26 19:46:50.712000+00:00                       NaT
# 412 2023-03-20 19:38:54.295000+00:00                       NaT
# 381 2023-03-24 17:08:12.617000+00:00                       NaT
#
#      is_remote_work                 city              state country  \
# 215           False       Rio de Janeiro     Rio de Janeiro  Brasil
# 198            True
# 270            True            São Paulo          São Paulo  Brasil
# 445           False  São José dos Campos          São Paulo  Brasil
# 196           False            São Paulo          São Paulo  Brasil
# 396            True             Sorocaba          São Paulo  Brasil
# 570           False         Porto Alegre  Rio Grande do Sul  Brasil
# 522           False             Salvador              Bahia  Brasil
# 582           False            São Paulo          São Paulo  Brasil
# 321            True            São Paulo          São Paulo  Brasil
# 337            True            São Paulo          São Paulo  Brasil
# 306           False            São Paulo          São Paulo  Brasil
# 331           False            São Paulo          São Paulo  Brasil
# 183           False                Bauru          São Paulo  Brasil
# 12            False              Barueri          São Paulo  Brasil
# 324           False             Blumenau     Santa Catarina  Brasil
# 305           False
# 552            True  Santana de Parnaíba          São Paulo  Brasil
# 412           False            São Paulo          São Paulo  Brasil
# 381            True
#
#                                                job_url  \
# 215  https://trescon.gupy.io/job/eyJqb2JJZCI6NDY1NT...
# 198  https://grupoboticario.gupy.io/job/eyJqb2JJZCI...
# 270  https://mutantbrvagas.gupy.io/job/eyJqb2JJZCI6...
# 445  https://embraer.gupy.io/job/eyJqb2JJZCI6NDM1MD...
# 196  https://recrutamentointernosimpar.gupy.io/job/...
# 396  https://afinz.gupy.io/job/eyJqb2JJZCI6NDQ4ODc3...
# 570  https://sicredi.gupy.io/job/eyJqb2JJZCI6MzkyMT...
# 522  https://larcopetroleo.gupy.io/job/eyJqb2JJZCI6...
# 582  https://peckadvogados.gupy.io/job/eyJqb2JJZCI6...
# 321  https://evermart.gupy.io/job/eyJqb2JJZCI6NDU2M...
# 337  https://sumicity.gupy.io/job/eyJqb2JJZCI6NDQ1N...
# 306  https://stefanini.gupy.io/job/eyJqb2JJZCI6NDU4...
# 331  https://libercapital.gupy.io/job/eyJqb2JJZCI6N...
# 183  https://servimed.gupy.io/job/eyJqb2JJZCI6NDY4N...
# 12   https://ttech.gupy.io/job/eyJqb2JJZCI6NDUzMDM2...
# 324  https://oliveiraeantunesadvogados.gupy.io/job/...
# 305  https://internationalexperienceitau.gupy.io/jo...
# 552  https://evow12.gupy.io/job/eyJqb2JJZCI6Mzk5Mjk...
# 412  https://vagasnutrien.gupy.io/job/eyJqb2JJZCI6N...
# 381  https://minsait.gupy.io/job/eyJqb2JJZCI6NDUwND...
#
#                                            company_url
# 215  https://trescon.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 198  https://grupoboticario.gupy.io/eyJzb3VyY2UiOiJ...
# 270  https://mutantbrvagas.gupy.io/eyJzb3VyY2UiOiJn...
# 445  https://embraer.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 196  https://recrutamentointernosimpar.gupy.io/eyJz...
# 396  https://afinz.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bv...
# 570  https://sicredi.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 522  https://larcopetroleo.gupy.io/eyJzb3VyY2UiOiJn...
# 582  https://peckadvogados.gupy.io/eyJzb3VyY2UiOiJn...
# 321  https://evermart.gupy.io/eyJzb3VyY2UiOiJndXB5X...
# 337  https://sumicity.gupy.io/eyJzb3VyY2UiOiJndXB5X...
# 306  https://stefanini.gupy.io/eyJzb3VyY2UiOiJndXB5...
# 331  https://libercapital.gupy.io/eyJzb3VyY2UiOiJnd...
# 183  https://servimed.gupy.io/eyJzb3VyY2UiOiJndXB5X...
# 12   https://ttech.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bv...
# 324  https://oliveiraeantunesadvogados.gupy.io/eyJz...
# 305  https://internationalexperienceitau.gupy.io/ey...
# 552  https://evow12.gupy.io/eyJzb3VyY2UiOiJndXB5X3B...
# 412  https://vagasnutrien.gupy.io/eyJzb3VyY2UiOiJnd...
# 381  https://minsait.gupy.io/eyJzb3VyY2UiOiJndXB5X3...

# %% [markdown]
# ## Load it
# Send the data to Bigquery

# %%
# use local json file to authenticate
SERVICE_ACCOUNT_JSON = r"..\job-tracker-384222-84c152151770.json"
client = bigquery.Client.from_service_account_json(SERVICE_ACCOUNT_JSON)

pandas_gbq.to_gbq(df_jobs, 'job_portal_data.gupy', project_id='job-tracker-384222', if_exists='append')
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
