# %% [markdown]
# # Job crawler - Gupy

# %% [markdown]
# #### Load Libs

# %%
import requests
import pandas as pd
from datetime import date
import time
import random
from google.cloud import bigquery
import pandas_gbq
import warnings
warnings. filterwarnings("ignore")

# %% [markdown]
# #### Load raw data

# %%
def normalize_columns(df):
    # Renomeando colunas
    df_new = df[['term','date_extraction', 'name', 'description', \
            'careerPageName', 'type', 'publishedDate', \
            'applicationDeadline', 'isRemoteWork', 'city', \
                'state', 'country', 'jobUrl', 'careerPageUrl']]
    
    df_new.rename(columns={'careerPageName': 'company_name', 
                            'publishedDate': 'published_date', 
                            'applicationDeadline': 'application_deadline', 
                            'isRemoteWork': 'is_remote_work', 
                            'jobUrl': 'job_url', 
                            'careerPageUrl': 'company_url'}, inplace=True)
    return df_new

# %%
# defining the url to get the data
url = "https://portal.api.gupy.io/api/job"

# defining the job title to search for
search_terms = ['Data', 'dados']

# defining the dataframe to store the data
df_jobs_raw = pd.DataFrame()

# defining today to use in some cases
today = date.today()

for term in search_terms:
    querystring = {"name":term,"offset":"1","limit":"5000"}

    time.sleep(random.randint(3, 6))
    r = requests.request("GET", url, params=querystring)

    data = r.json()

    df_term = pd.json_normalize(data, record_path =['data'])
    df_term['term'] = term
    df_term['date_extraction'] = today

    df_jobs_raw = pd.concat([df_jobs_raw, df_term], ignore_index=True)
    df_jobs_normalized = normalize_columns(df_jobs_raw)

df_jobs = df_jobs_normalized.copy()

display(df_jobs.head())
# Out:
#    term date_extraction                                               name  \
# 0  Data      2023-04-19   Analista Data Center JR - Virtualização (VMWare)
# 1  Data      2023-04-19  ANALISTA II BIG DATA - GOIÂNIA/GO II || POI - ...
# 2  Data      2023-04-19                           Estágio em Data Quality
# 3  Data      2023-04-19                  Assistente de Data Quality [LETT]
# 4  Data      2023-04-19            Assistente de Data Quality (Manutenção)
#
#                                          description  \
# 0  SOBRE A EMPRESA:A Unidade de Negócio de Cloud ...
# 1  Para compor ainda mais esse time de sucesso, b...
# 2  Quer fazer parte de um time alta performance?&...
# 3  Quer fazer parte de um time alta performance?&...
# 4  Quer fazer parte de um time alta performance?&...
#
#                                 company_name                     type  \
# 0                            Telefónica Tech   vacancy_type_effective
# 1  Evolução profissional a gente faz em casa   vacancy_type_effective
# 2                          Neogrid Carreiras  vacancy_type_internship
# 3                          Neogrid Carreiras   vacancy_type_effective
# 4                          Neogrid Carreiras   vacancy_type_effective
#
#              published_date application_deadline  is_remote_work  \
# 0  2023-04-19T12:05:04.822Z                 None           False
# 1  2023-04-18T19:14:00.918Z                 None           False
# 2  2023-04-18T17:48:42.627Z                 None            True
# 3  2023-04-18T17:27:18.497Z                 None            True
# 4  2023-04-18T17:25:43.453Z                 None           False
#
#                   city              state country  \
# 0  Santana de Parnaíba          São Paulo  Brasil
# 1              Goiânia              Goiás  Brasil
# 2         Porto Alegre  Rio Grande do Sul  Brasil
# 3            São Paulo          São Paulo  Brasil
# 4            São Paulo          São Paulo  Brasil
#
#                                              job_url  \
# 0  https://ttech.gupy.io/job/eyJqb2JJZCI6NDcwMzc0...
# 1  https://poi.gupy.io/job/eyJqb2JJZCI6NDY5ODUyNy...
# 2  https://neogridcarreiras.gupy.io/job/eyJqb2JJZ...
# 3  https://neogridcarreiras.gupy.io/job/eyJqb2JJZ...
# 4  https://neogridcarreiras.gupy.io/job/eyJqb2JJZ...
#
#                                          company_url
# 0  https://ttech.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bv...
# 1  https://poi.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bvcn...
# 2  https://neogridcarreiras.gupy.io/eyJzb3VyY2UiO...
# 3  https://neogridcarreiras.gupy.io/eyJzb3VyY2UiO...
# 4  https://neogridcarreiras.gupy.io/eyJzb3VyY2UiO...

# %% [markdown]
# #### Understanding and cleaning data

# %%
df_jobs.describe()
# Out:
#          term date_extraction               name  \
# count     692             692                692
# unique      2               1                599
# top     dados      2023-04-19  Analista de Dados
# freq      547             692                 17
#
#                                               description     company_name  \
# count                                                 692              692
# unique                                                666              360
# top     Destinado a formados dos cursos de Sistemas de...  Stefanini Group
# freq                                                    4               19
#
#                           type            published_date  \
# count                      692                       692
# unique                       8                       685
# top     vacancy_type_effective  2023-02-28T01:13:17.152Z
# freq                       518                         2
#
#             application_deadline is_remote_work       city      state country  \
# count                         33            692        692        692     692
# unique                        16              2         98         17       8
# top     2023-04-24T00:00:00.000Z          False  São Paulo  São Paulo  Brasil
# freq                           5            436        240        344     605
#
#                                                   job_url  \
# count                                                 692
# unique                                                685
# top     https://peers.gupy.io/job/eyJqb2JJZCI6NDI4MTc4...
# freq                                                    2
#
#                                               company_url
# count                                                 692
# unique                                                364
# top     https://stefanini.gupy.io/eyJzb3VyY2UiOiJndXB5...
# freq                                                   19

# %% [markdown]
# ##### Change datatypes

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   term                  692 non-null    object
#  1   date_extraction       692 non-null    object
#  2   name                  692 non-null    object
#  3   description           692 non-null    object
#  4   company_name          692 non-null    object
#  5   type                  692 non-null    object
#  6   published_date        692 non-null    object
#  7   application_deadline  33 non-null     object
#  8   is_remote_work        692 non-null    bool
#  9   city                  692 non-null    object
#  10  state                 692 non-null    object
#  11  country               692 non-null    object
#  12  job_url               692 non-null    object
#  13  company_url           692 non-null    object
# dtypes: bool(1), object(13)
# memory usage: 71.1+ KB

# %%
# change columns to datetime
cols = ['date_extraction', 'application_deadline', 'published_date']

for col in cols:
    df_jobs[col] = pd.to_datetime(df_jobs[col], format="%Y-%m-%d")

# %%
# change columns to category
cols = ['term', 'type', 'city', 'state', 'country']

for col in cols:
    df_jobs[col] = df_jobs[col].astype('category')

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   term                  692 non-null    category
#  1   date_extraction       692 non-null    datetime64[ns]
#  2   name                  692 non-null    object
#  3   description           692 non-null    object
#  4   company_name          692 non-null    object
#  5   type                  692 non-null    category
#  6   published_date        692 non-null    datetime64[ns, UTC]
#  7   application_deadline  33 non-null     datetime64[ns, UTC]
#  8   is_remote_work        692 non-null    bool
#  9   city                  692 non-null    category
#  10  state                 692 non-null    category
#  11  country               692 non-null    category
#  12  job_url               692 non-null    object
#  13  company_url           692 non-null    object
# dtypes: bool(1), category(5), datetime64[ns, UTC](2), datetime64[ns](1), object(5)
# memory usage: 51.8+ KB

# %% [markdown]
# ##### Check missing values

# %%
df_jobs.isna().sum()
# Out:
# term                      0
# date_extraction           0
# name                      0
# description               0
# company_name              0
# type                      0
# published_date            0
# application_deadline    659
# is_remote_work            0
# city                      0
# state                     0
# country                   0
# job_url                   0
# company_url               0
# dtype: int64

# %% [markdown]
# ##### Fixing duplicated values

# %%
# check for duplicated rows
df_jobs.duplicated().sum()
# Out:
# 0

# %%
# see if any data is duplicated for job_url column and drop it
print(f"Duplicated before: {df_jobs.duplicated(subset='job_url').sum()}" )
df_jobs.drop_duplicates(subset='job_url', inplace=True)

print(f"Duplicated after: {df_jobs.duplicated(subset='job_url').sum()}")
# Out:
# Duplicated before: 7
# Duplicated after: 0

# %%
df_jobs.sample(20)
# Out:
#       term date_extraction                                               name  \
# 678  dados      2023-04-19                                 Cientista de Dados
# 427  dados      2023-04-19                         Pessoa Gerente de Dados SR
# 459  dados      2023-04-19  Coordenador(a) de Dados - área de Prevenção a ...
# 413  dados      2023-04-19      PESSOA DESENVOLVEDORA - AUTOMAÇÃO SR (DADOS)
# 551  dados      2023-04-19                     [Dados e BI] Analista de dados
# 593  dados      2023-04-19  Advogado(a) Pleno | Privacidade e Proteção de ...
# 263  dados      2023-04-19                        Assistente de Base de Dados
# 76    Data      2023-04-19                    Danone - Master Data Manager W3
# 600  dados      2023-04-19            Especialista Banco de Dados - Projetos
# 20    Data      2023-04-19                         Estágio - Data Science NE
# 261  dados      2023-04-19                        PESSOA CIENTISTA DE DADOS
# 546  dados      2023-04-19           Engenharia de Dados Pleno - Crédito PF 🧡
# 257  dados      2023-04-19                  Analista de Governança Dados - Sr
# 284  dados      2023-04-19              Analista de Dados Estatísticos Sênior
# 519  dados      2023-04-19  BANCO DE DADOS- VAGAS ADMINISTRATIVAS EXCLUSIV...
# 381  dados      2023-04-19                   Administrador de Banco de Dados
# 292  dados      2023-04-19                Assistente de Inteligência de Dados
# 672  dados      2023-04-19  Banco de Dados - Gerente de Negócios   - Ranch...
# 613  dados      2023-04-19  Banco de Talentos - Analista de Inteligência d...
# 559  dados      2023-04-19                      Analista sênior de Dados - SP
#
#                                            description  \
# 678  Vaga para nosso BANCO DE TALENTOSProcuramos Ci...
# 427  Venha conosco imaginar o amanhã, cuidar do hoj...
# 459  A iuguSomos a primeira plataforma online do Br...
# 413  AQUI SUA CARREIRA COMEÇA GRANDE.VENHA SER UMA ...
# 551  Estamos procurando um Analista de Dados para c...
# 593  Se você é apaixonado(a) por Direito, Tecnologi...
# 263  Aqui na Nelogica, desenvolvemos soluções para ...
# 76   We have an amazing opportunity in our Mexico C...
# 600  Vice-Presidência: VP B2BDiretoria: Unidade de ...
# 20   Destinado a universitários dos cursos de Engen...
# 261  A NAVA está em busca de uma&nbsp;Pessoa Cienti...
# 546  Vem fazer o Itaú_Somos o Maior banco da Améric...
# 257  Impulsionamos seu negócio, gerando impacto na ...
# 284  Trabalhamos pensando no presente e no futuro d...
# 519  Cuidar da Água para Transformar a Qualidade de...
# 381  A Minsait é uma companhia global de tecnologia...
# 292  Se você gosta de trabalhar com análises numéri...
# 672  O Banco de talentos visa aproximar das nossas ...
# 613  Conhecendo um pouco mais sobre a Americanas S....
# 559  Somos um dos escritórios de advocacia líderes ...
#
#                                       company_name                      type  \
# 427  https://getnet.gupy.io/job/eyJqb2JJZCI6NDQ2MjM...
# 459  https://iugu.gupy.io/job/eyJqb2JJZCI6NDMzMDY0N...
# 413  https://yduqstech.gupy.io/job/eyJqb2JJZCI6NDQ2...
# 551  https://beepsaude.gupy.io/job/eyJqb2JJZCI6Mzk0...
# 593  https://peckadvogados.gupy.io/job/eyJqb2JJZCI6...
# 263  https://nelogica.gupy.io/job/eyJqb2JJZCI6NDYyN...
# 76   https://pageoutsourcingmx.gupy.io/job/eyJqb2JJ...
# 600  https://vivo.gupy.io/job/eyJqb2JJZCI6MzY5ODA2O...
# 20   https://visagio.gupy.io/job/eyJqb2JJZCI6NDYxOD...
# 261  https://nava.gupy.io/job/eyJqb2JJZCI6NDYyNjY5M...
# 546  https://vemproitau.gupy.io/job/eyJqb2JJZCI6NDA...
# 257  https://minsait.gupy.io/job/eyJqb2JJZCI6NDYyOD...
# 284  https://digitalgpa.gupy.io/job/eyJqb2JJZCI6NDU...
# 519  https://tigre.gupy.io/job/eyJqb2JJZCI6NDA5NTY1...
# 381  https://minsait.gupy.io/job/eyJqb2JJZCI6NDUwND...
# 292  https://vagas_confi_denciais.gupy.io/job/eyJqb...
# 672  https://sicredi.gupy.io/job/eyJqb2JJZCI6MTI3MT...
# 613  https://americanas.gupy.io/job/eyJqb2JJZCI6MzY...
# 559  https://mattosfilho.gupy.io/job/eyJqb2JJZCI6Mz...
#
#                                            company_url
# 678  https://brivia.gupy.io/eyJzb3VyY2UiOiJndXB5X3B...
# 427  https://getnet.gupy.io/eyJzb3VyY2UiOiJndXB5X3B...
# 459  https://iugu.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bvc...
# 413  https://yduqstech.gupy.io/eyJzb3VyY2UiOiJndXB5...
# 551  https://beepsaude.gupy.io/eyJzb3VyY2UiOiJndXB5...
# 593  https://peckadvogados.gupy.io/eyJzb3VyY2UiOiJn...
# 263  https://nelogica.gupy.io/eyJzb3VyY2UiOiJndXB5X...
# 76   https://pageoutsourcingmx.gupy.io/eyJzb3VyY2Ui...
# 600  https://vivo.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bvc...
# 20   https://visagio.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 261  https://nava.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bvc...
# 546  https://vemproitau.gupy.io/eyJzb3VyY2UiOiJndXB...
# 257  https://minsait.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 284  https://digitalgpa.gupy.io/eyJzb3VyY2UiOiJndXB...
# 519  https://tigre.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bv...
# 381  https://minsait.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 292
# 672  https://sicredi.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 613  https://americanas.gupy.io/eyJzb3VyY2UiOiJndXB...
# 559  https://mattosfilho.gupy.io/eyJzb3VyY2UiOiJndX...

# %% [markdown]
# ## Load it
# Send the data to Bigquery

# %%
# use local json file to authenticate
SERVICE_ACCOUNT_JSON = r"D:\DataAnalytics\projects\jobs_tracker\job-tracker-384222-84c152151770.json"
client = bigquery.Client.from_service_account_json(SERVICE_ACCOUNT_JSON)

pandas_gbq.to_gbq(df_jobs, 'job_portal_data.gupy', project_id='job-tracker-384222', if_exists='append')
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 990.16it/s]
