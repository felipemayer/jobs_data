# %% [markdown]
# # Job crawler - Gupy

# %% [markdown]
# #### Load Libs

# %%
import requests
import pandas as pd
from datetime import date
import time
import random
from google.cloud import bigquery
import pandas_gbq
import warnings
warnings. filterwarnings("ignore")

# %% [markdown]
# #### Load raw data

# %%
def normalize_columns(df):
    # Renomeando colunas
    df_new = df[['portal', 'term','date_extraction', 'name', 'description', \
            'careerPageName', 'type', 'publishedDate', \
            'applicationDeadline', 'isRemoteWork', 'city', \
                'state', 'country', 'jobUrl', 'careerPageUrl']]
    
    df_new.rename(columns={'careerPageName': 'company_name', 
                            'publishedDate': 'published_date', 
                            'applicationDeadline': 'application_deadline', 
                            'isRemoteWork': 'is_remote_work', 
                            'jobUrl': 'job_url', 
                            'careerPageUrl': 'company_url'}, inplace=True)
    return df_new

# %%
# defining the url to get the data
url = "https://portal.api.gupy.io/api/job"

# defining the job title to search for
search_terms = ['data', 'dados', 'product', 'engenharia', 'back-end', 'front-end']

# defining the dataframe to store the data
df_jobs_raw = pd.DataFrame()

# defining today to use in some cases
today = date.today()

for term in search_terms:
    querystring = {"name":term,"offset":"1","limit":"5000"}

    time.sleep(random.randint(3, 6))
    r = requests.request("GET", url, params=querystring)

    data = r.json()

    df_term = pd.json_normalize(data, record_path =['data'])
    df_term['portal'] = "Gupy"
    df_term['term'] = term
    df_term['date_extraction'] = today

    df_jobs_raw = pd.concat([df_jobs_raw, df_term], ignore_index=True)
    df_jobs_normalized = normalize_columns(df_jobs_raw)

df_jobs = df_jobs_normalized.copy()

display(df_jobs.head())
# Out:
#   portal  term date_extraction  \
# 0   Gupy  data      2023-04-20
# 1   Gupy  data      2023-04-20
# 2   Gupy  data      2023-04-20
# 3   Gupy  data      2023-04-20
# 4   Gupy  data      2023-04-20
#
#                                                 name  \
# 0   Analista Data Center JR - Virtualização (VMWare)
# 1  ANALISTA II BIG DATA - GOIÂNIA/GO II || POI - ...
# 2                           Estágio em Data Quality
# 3                  Assistente de Data Quality [LETT]
# 4            Assistente de Data Quality (Manutenção)
#
#                                          description  \
# 0  SOBRE A EMPRESA:A Unidade de Negócio de Cloud ...
# 1  Para compor ainda mais esse time de sucesso, b...
# 2  Quer fazer parte de um time alta performance?&...
# 3  Quer fazer parte de um time alta performance?&...
# 4  Quer fazer parte de um time alta performance?&...
#
#                                 company_name                     type  \
# 0                            Telefónica Tech   vacancy_type_effective
# 1  Evolução profissional a gente faz em casa   vacancy_type_effective
# 2                          Neogrid Carreiras  vacancy_type_internship
# 3                          Neogrid Carreiras   vacancy_type_effective
# 4                          Neogrid Carreiras   vacancy_type_effective
#
#              published_date application_deadline  is_remote_work  \
# 0  2023-04-19T12:05:04.822Z                 None           False
# 1  2023-04-18T19:14:00.918Z                 None           False
# 2  2023-04-18T17:48:42.627Z                 None            True
# 3  2023-04-18T17:27:18.497Z                 None            True
# 4  2023-04-18T17:25:43.453Z                 None           False
#
#                   city              state country  \
# 0  Santana de Parnaíba          São Paulo  Brasil
# 1              Goiânia              Goiás  Brasil
# 2         Porto Alegre  Rio Grande do Sul  Brasil
# 3            São Paulo          São Paulo  Brasil
# 4            São Paulo          São Paulo  Brasil
#
#                                              job_url  \
# 0  https://ttech.gupy.io/job/eyJqb2JJZCI6NDcwMzc0...
# 1  https://poi.gupy.io/job/eyJqb2JJZCI6NDY5ODUyNy...
# 2  https://neogridcarreiras.gupy.io/job/eyJqb2JJZ...
# 3  https://neogridcarreiras.gupy.io/job/eyJqb2JJZ...
# 4  https://neogridcarreiras.gupy.io/job/eyJqb2JJZ...
#
#                                          company_url
# 0  https://ttech.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bv...
# 1  https://poi.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bvcn...
# 2  https://neogridcarreiras.gupy.io/eyJzb3VyY2UiO...
# 3  https://neogridcarreiras.gupy.io/eyJzb3VyY2UiO...
# 4  https://neogridcarreiras.gupy.io/eyJzb3VyY2UiO...

# %% [markdown]
# #### Understanding and cleaning data

# %%
df_jobs.describe()
# Out:
#        portal        term date_extraction           name  \
# count    1895        1895            1895           1895
# unique      1           6               1           1588
# top      Gupy  engenharia      2023-04-20  Product Owner
# freq     1895         727            1895             18
#
#                                               description   company_name  \
# count                                                1895           1895
# unique                                               1766            772
# top     Falar da MRV&amp;CO (MRV, Urba, Luggo, Sensia ...  Itaú Unibanco
# freq                                                   11             67
#
#                           type            published_date  \
# count                     1895                      1895
# unique                      12                      1853
# top     vacancy_type_effective  2023-03-17T17:57:26.262Z
# freq                      1165                         2
#
#             application_deadline is_remote_work       city      state country  \
# count                         87           1895       1895       1895    1895
# unique                        26              2        250         26       9
# top     2023-04-30T00:00:00.000Z          False  São Paulo  São Paulo  Brasil
# freq                          14           1300        501        885    1713
#
#                                                   job_url  \
# count                                                1895
# unique                                               1853
# top     https://agasus.gupy.io/job/eyJqb2JJZCI6NDQ2OTk...
# freq                                                    2
#
#                                               company_url
# count                                                1895
# unique                                                786
# top     https://vemproitau.gupy.io/eyJzb3VyY2UiOiJndXB...
# freq                                                   67

# %% [markdown]
# ##### Change datatypes

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1895 entries, 0 to 1894
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   portal                1895 non-null   object
#  1   term                  1895 non-null   object
#  2   date_extraction       1895 non-null   object
#  3   name                  1895 non-null   object
#  4   description           1895 non-null   object
#  5   company_name          1895 non-null   object
#  6   type                  1895 non-null   object
#  7   published_date        1895 non-null   object
#  8   application_deadline  87 non-null     object
#  9   is_remote_work        1895 non-null   bool
#  10  city                  1895 non-null   object
#  11  state                 1895 non-null   object
#  12  country               1895 non-null   object
#  13  job_url               1895 non-null   object
#  14  company_url           1895 non-null   object
# dtypes: bool(1), object(14)
# memory usage: 209.2+ KB

# %%
# change columns to datetime
cols = ['date_extraction', 'application_deadline', 'published_date']

for col in cols:
    df_jobs[col] = pd.to_datetime(df_jobs[col], format="%Y-%m-%d")

# %%
# change columns to category
cols = ['term', 'type', 'city', 'state', 'country']

for col in cols:
    df_jobs[col] = df_jobs[col].astype('category')

# %%
df_jobs['published_date']
# Out:
# 0      2023-04-19 12:05:04.822000+00:00
# 1      2023-04-18 19:14:00.918000+00:00
# 2      2023-04-18 17:48:42.627000+00:00
# 3      2023-04-18 17:27:18.497000+00:00
# 4      2023-04-18 17:25:43.453000+00:00
#                      ...
# 1890          2022-02-21 19:08:33+00:00
# 1891          2022-01-14 20:28:01+00:00
# 1892          2021-08-24 17:31:51+00:00
# 1893          2021-06-04 22:33:05+00:00
# 1894          2018-05-24 17:22:36+00:00
# Name: published_date, Length: 1895, dtype: datetime64[ns, UTC]

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1895 entries, 0 to 1894
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   portal                1895 non-null   object
#  1   term                  1895 non-null   category
#  2   date_extraction       1895 non-null   datetime64[ns]
#  3   name                  1895 non-null   object
#  4   description           1895 non-null   object
#  5   company_name          1895 non-null   object
#  6   type                  1895 non-null   category
#  7   published_date        1895 non-null   datetime64[ns, UTC]
#  8   application_deadline  87 non-null     datetime64[ns, UTC]
#  9   is_remote_work        1895 non-null   bool
#  10  city                  1895 non-null   category
#  11  state                 1895 non-null   category
#  12  country               1895 non-null   category
#  13  job_url               1895 non-null   object
#  14  company_url           1895 non-null   object
# dtypes: bool(1), category(5), datetime64[ns, UTC](2), datetime64[ns](1), object(6)
# memory usage: 158.6+ KB

# %% [markdown]
# ##### Check missing values

# %%
df_jobs.isna().sum()
# Out:
# portal                     0
# term                       0
# date_extraction            0
# name                       0
# description                0
# company_name               0
# type                       0
# published_date             0
# application_deadline    1808
# is_remote_work             0
# city                       0
# state                      0
# country                    0
# job_url                    0
# company_url                0
# dtype: int64

# %% [markdown]
# ##### Fixing duplicated values

# %%
# check for duplicated rows
df_jobs.duplicated().sum()
# Out:
# 0

# %%
# see if any data is duplicated for job_url column and drop it
print(f"Duplicated before: {df_jobs.duplicated(subset='job_url').sum()}" )
df_jobs.drop_duplicates(subset='job_url', inplace=True)

print(f"Duplicated after: {df_jobs.duplicated(subset='job_url').sum()}")
# Out:
# Duplicated before: 42
# Duplicated after: 0

# %%
df_jobs.sample(20)
# Out:
#      portal        term date_extraction  \
# 686    Gupy       dados      2023-04-20
# 937    Gupy  engenharia      2023-04-20
# 957    Gupy  engenharia      2023-04-20
# 1222   Gupy  engenharia      2023-04-20
# 1739   Gupy    back-end      2023-04-20
# 1327   Gupy  engenharia      2023-04-20
# 638    Gupy       dados      2023-04-20
# 1081   Gupy  engenharia      2023-04-20
# 550    Gupy       dados      2023-04-20
# 979    Gupy  engenharia      2023-04-20
# 517    Gupy       dados      2023-04-20
# 609    Gupy       dados      2023-04-20
# 491    Gupy       dados      2023-04-20
# 1794   Gupy   front-end      2023-04-20
# 574    Gupy       dados      2023-04-20
# 1652   Gupy  engenharia      2023-04-20
# 1041   Gupy  engenharia      2023-04-20
# 729    Gupy     product      2023-04-20
# 1143   Gupy  engenharia      2023-04-20
# 201    Gupy       dados      2023-04-20
#
#                                                    name  \
# 686   Você tem interesse em ingressar na área de Eng...
# 937                 Estagiário em Engenharia de Produto
# 957          Tutor Facilitador Estratégico - Engenharia
# 1222  PROFESSOR(A) DE MUSCULAÇÃO - CLUBE DE ENGENHARIA
# 1739           Desenvolvedor Back End SR (foco em .NET)
# 1327  BANCO DE TALENTOS: ESTAGIÁRIO DE ENGENHARIA ME...
# 638               Administrador de Banco de Dados (DBA)
# 1081             ANALISTA DE ENGENHARIA DE PROCESSOS SR
# 550                                   Analista de Dados
# 979   Estágio Engenharia Civil/Arquitetura - Rio de ...
# 517   BANCO DE DADOS- VAGAS ADMINISTRATIVAS EXCLUSIV...
# 609   Banco de Talentos - Especialista em Ciência de...
# 491     Estágio em Análises de Dados | Guararapes Natal
# 1794           Pessoa Desenvolvedora Sênior | Front End
# 574        Formados - Tecnologia | Automação e Dados SP
# 1652                     [BANCO DE TALENTOS] Engenharia
# 1041                      Consultor Engenharia Clínica
# 729    Associate Product Owner - Uberlândia/MG e Remoto
# 1143                  PROFESSOR A - ENGENHARIA ELÉTRICA
# 201       Engenheiro de Dados AWS (Home Office/Brasil)
#
#                                             description  \
# 686   Nossa nave tem um lugar reservado pra você! Va...
# 937   Vaga para o time de Pesquisa &amp; Desenvolvim...
# 957   Queremos recebê-lo (a) no Universo do Conhecim...
# 1222  A&nbsp;Bluefit&nbsp;é uma rede de academias br...
# 1739  A Gipsyy é uma startup de tecnologia com o DNA...
# 1327  Atuamos no desenvolvimento de projetos para os...
# 638   Olá, nós somos a Jazz!&nbsp;&nbsp;Somos uma pl...
# 1081  Atuar na engenharia de processos para novas fe...
# 550   A Leads2b é uma empresa de tecnologia, SaaS B2...
# 979   Falar da MRV&amp;CO (MRV, Urba, Luggo, Sensia ...
# 517   Cuidar da Água para Transformar a Qualidade de...
# 609   Conhecendo um pouco mais sobre a Americanas S....
# 491   Aqui na Riachuelo a gente se conecta com você!...
# 1794  Dados. Tecnologia. Fibra. Somos a Oi, somos mi...
# 574   Destinado a formados dos cursos de Sistemas de...
# 1652  Oi! Esse aqui é o BANCO DE TALENTOS da Árvore,...
# 1041  A hora de fazer parte de um time comprometido,...
# 729   Buscamos uma pessoa para atuar como Associate ...
# 1143  A&nbsp;Cogna&nbsp;tem mais de 50 anos de tradi...
# 201   Nosso negócioAqui na Programmers, aceleramos g...
#
#                                company_name                      type  \
# 686                                Semantix  vacancy_type_talent_pool
# 937                              BYD Brasil   vacancy_type_internship
# 957                              Unicesumar    vacancy_type_effective
# 1222                       Bluefit Academia    vacancy_type_effective
# 1739                                 Gipsyy    vacancy_type_effective
# 1327                     SANDECH Engenharia   vacancy_type_internship
# 638                               Jazz Tech    vacancy_type_effective
# 1081                          Itaú Unibanco    vacancy_type_temporary
# 550                                 Leads2b    vacancy_type_effective
# 979   Venha construir o futuro com a gente!   vacancy_type_internship
# 517                             Grupo Tigre  vacancy_type_talent_pool
# 609                         Americanas S.A.  vacancy_type_talent_pool
# 491                              Riachuelo    vacancy_type_internship
# 1794                                     Oi    vacancy_type_effective
# 574                                 Visagio  vacancy_type_talent_pool
# 1652                                 Árvore  vacancy_type_talent_pool
# 1041          Hapvida NotreDame Intermédica    vacancy_type_effective
# 729              Sankhya Gestão de Negócios    vacancy_type_effective
# 1143                         Cogna Educação    vacancy_type_effective
# 201                     Vem Ser Programmers    vacancy_type_effective
#
#                        published_date      application_deadline  \
# 686         2020-12-05 21:45:14+00:00                       NaT
# 937  2023-04-19 19:50:32.353000+00:00                       NaT
# 957  2023-04-19 13:00:05.520000+00:00                       NaT
# 1222 2023-03-29 13:23:29.439000+00:00                       NaT
# 1739 2023-01-19 14:54:08.705000+00:00                       NaT
# 1327 2023-03-13 19:17:08.064000+00:00                       NaT
# 638  2022-10-20 17:00:07.927000+00:00                       NaT
# 1081 2023-04-11 15:46:17.075000+00:00                       NaT
# 550  2023-01-26 16:37:02.521000+00:00                       NaT
# 979  2023-04-18 13:17:03.760000+00:00                       NaT
# 517  2023-02-13 20:48:22.117000+00:00                       NaT
# 609  2022-12-12 20:02:35.498000+00:00                       NaT
# 491  2023-02-27 18:43:31.384000+00:00                       NaT
# 1794 2023-04-06 12:23:42.521000+00:00 2023-04-21 00:00:00+00:00
# 574  2023-01-07 20:25:49.637000+00:00                       NaT
# 1652        2020-10-18 00:08:17+00:00                       NaT
# 1041 2023-04-13 13:12:31.309000+00:00                       NaT
# 729  2023-04-12 12:52:53.789000+00:00 2023-04-26 00:00:00+00:00
# 1143 2023-04-05 11:26:36.659000+00:00                       NaT
# 201  2023-04-14 20:28:05.066000+00:00                       NaT
#
#       is_remote_work            city                state country  \
# 686             True       São Paulo            São Paulo  Brasil
# 937            False        Campinas            São Paulo  Brasil
# 957            False       Apucarana               Paraná  Brasil
# 1222           False        Brasilia     Distrito Federal  Brasil
# 1739           False       São Paulo            São Paulo  Brasil
# 1327           False  Rio de Janeiro       Rio de Janeiro  Brasil
# 638            False       São Paulo            São Paulo  Brasil
# 1081           False       Sao Paulo            São Paulo  Brasil
# 550            False        Curitiba               Paraná  Brasil
# 979            False  Rio de Janeiro       Rio de Janeiro  Brasil
# 517            False       Joinville       Santa Catarina  Brasil
# 609             True
# 491            False           Natal  Rio Grande do Norte  Brasil
# 1794            True  Rio de Janeiro       Rio de Janeiro  Brasil
# 574            False       São Paulo            São Paulo  Brasil
# 1652            True  Rio de Janeiro       Rio de Janeiro  Brasil
# 1041           False       Fortaleza                Ceará  Brasil
# 729             True      Uberlândia         Minas Gerais  Brasil
# 1143           False        Salvador                Bahia  Brasil
# 201             True       São Paulo            São Paulo  Brasil
#
#                                                 job_url  \
# 686   https://semantix.gupy.io/job/eyJqb2JJZCI6NjA0N...
# 937   https://bydbrasil.gupy.io/job/eyJqb2JJZCI6NDcw...
# 957   https://unicesumaroficial.gupy.io/job/eyJqb2JJ...
# 1222  https://bluefit.gupy.io/job/eyJqb2JJZCI6NDUxOD...
# 1739  https://vempragipsyy.gupy.io/job/eyJqb2JJZCI6M...
# 1327  https://sandech.gupy.io/job/eyJqb2JJZCI6NDQ0Mz...
# 638   https://jazztech.gupy.io/job/eyJqb2JJZCI6MzI0N...
# 1081  https://vemproitau.gupy.io/job/eyJqb2JJZCI6NDU...
# 550   https://leads2b.gupy.io/job/eyJqb2JJZCI6Mzk5MT...
# 979   https://vagas-mrveco.gupy.io/job/eyJqb2JJZCI6N...
# 517   https://tigre.gupy.io/job/eyJqb2JJZCI6NDA5NTY1...
# 609   https://americanas.gupy.io/job/eyJqb2JJZCI6MzY...
# 491   https://riachuelo.gupy.io/job/eyJqb2JJZCI6NDI3...
# 1794  https://oi.gupy.io/job/eyJqb2JJZCI6NDU4NTgxNCw...
# 574   https://visagio.gupy.io/job/eyJqb2JJZCI6Mzg1MD...
# 1652  https://arvore.gupy.io/job/eyJqb2JJZCI6NTI2NTQ...
# 1041  https://sistemahapvida.gupy.io/job/eyJqb2JJZCI...
# 729   https://sankhya.gupy.io/job/eyJqb2JJZCI6NDYzNz...
# 1143  https://cogna.gupy.io/job/eyJqb2JJZCI6NDU4NDU0...
# 201   https://programmers.gupy.io/job/eyJqb2JJZCI6ND...
#
#                                             company_url
# 686   https://semantix.gupy.io/eyJzb3VyY2UiOiJndXB5X...
# 937   https://bydbrasil.gupy.io/eyJzb3VyY2UiOiJndXB5...
# 957   https://unicesumaroficial.gupy.io/eyJzb3VyY2Ui...
# 1222  https://bluefit.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 1739  https://vempragipsyy.gupy.io/eyJzb3VyY2UiOiJnd...
# 1327  https://sandech.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 638   https://jazztech.gupy.io/eyJzb3VyY2UiOiJndXB5X...
# 1081  https://vemproitau.gupy.io/eyJzb3VyY2UiOiJndXB...
# 550   https://leads2b.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 979   https://vagas-mrveco.gupy.io/eyJzb3VyY2UiOiJnd...
# 517   https://tigre.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bv...
# 609   https://americanas.gupy.io/eyJzb3VyY2UiOiJndXB...
# 491   https://riachuelo.gupy.io/eyJzb3VyY2UiOiJndXB5...
# 1794  https://oi.gupy.io/eyJzb3VyY2UiOiJndXB5X3BvcnR...
# 574   https://visagio.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 1652  https://arvore.gupy.io/eyJzb3VyY2UiOiJndXB5X3B...
# 1041  https://sistemahapvida.gupy.io/eyJzb3VyY2UiOiJ...
# 729   https://sankhya.gupy.io/eyJzb3VyY2UiOiJndXB5X3...
# 1143  https://cogna.gupy.io/eyJzb3VyY2UiOiJndXB5X3Bv...
# 201   https://programmers.gupy.io/eyJzb3VyY2UiOiJndX...

# %% [markdown]
# ## Load it
# Send the data to Bigquery

# %%
# use local json file to authenticate
SERVICE_ACCOUNT_JSON = r"..\job-tracker-384222-84c152151770.json"
client = bigquery.Client.from_service_account_json(SERVICE_ACCOUNT_JSON)

pandas_gbq.to_gbq(df_jobs, 'job_portal_data.gupy', project_id='job-tracker-384222', if_exists='append')
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
